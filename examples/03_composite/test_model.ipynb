# %%
from src.model import DrawFalconLetters, DrawSnake, SimulateData
import numpy as np
import pylab as plt

# %%
sim1 = DrawFalconLetters()
sim2 = DrawSnake()
sim3 = SimulateData()

z1 = np.array([[-0.8, -0.8],
                [0.0, -0.8],
                [0.8, -0.8],
                [-0.8, 0.7],
                [0.0, 0.7],
                [0.8, 0.7]]).flatten()
z2 = 8*np.linspace(0, 2, 31)**0.5

img1 = sim1.simulate(z1)
img2 = sim2.simulate(z2)
x = sim3.simulate(img1, img2)

plt.imshow(x, cmap='gray')

# %%
np.save("./data/x_obs.npy", x)
