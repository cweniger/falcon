# %%
import numpy as np

# %%
x = np.random.randn(10000)
x = np.float32(x)
x
# Out:
# array([-0.8656994 , -0.57489574,  1.1123825 , ..., -0.8901346 ,
#        -1.6563998 ,  0.6497917 ], shape=(10000,), dtype=float32)

# %%
np.save("observed.npy", x)
