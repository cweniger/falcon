# %%
import numpy as np
import torch
import pylab as plt

import model

# %%
z = np.random.rand(5)*2 - 1 
y = model.Signal().simulate(z)
n = model.Noise().simulate()
x = model.Data().simulate(y, n)
plt.plot(x)
