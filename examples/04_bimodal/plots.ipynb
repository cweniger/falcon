# %%
import joblib
import numpy as np
import pylab as plt
import torch

# %%
x = torch.load("outputs/2025-09-21/17-46-37/graph_dir/z/train_id_history.pth")
y = torch.load("outputs/2025-09-21/17-46-37/graph_dir/z/validation_id_history.pth")
x = np.array(x)
y = np.array(y)
t0 = x[:, 0].min()
plt.scatter(x[:, 0]-t0, x[:, 1], marker='.', label='train')
plt.scatter(y[:, 0]-t0, y[:, 1], marker='.', label='validation')
plt.xlabel("time [sec]")
plt.ylabel("simulation ID")
plt.legend()

# %%
#samples = joblib.load("samples_posterior.joblib")
#samples = joblib.load("post_14-33-32.joblib")
samples = joblib.load("post_14-54-29.joblib")
z = np.array([sample['z'] for sample in samples])

# %%
plt.scatter(z[:, 0], z[:, 3], alpha=0.5, marker='.')
